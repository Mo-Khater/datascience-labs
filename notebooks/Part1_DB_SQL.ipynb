# %% [markdown]
# # <span style="color:blue">Applied Data Science - Tutorial 02</span>
#
# ---

# %% [markdown]
# ### Installation

# %%
# # # Core libraries
# # !pip install pandas numpy

# # # Database
# !pip install sqlalchemy

# # # APIs
# !pip install requests python-dotenv

# # # Web scraping
# !pip install beautifulsoup4 lxml

# # # Data formats
# !pip install openpyxl xlrd

# # # Optional but recommended
# !pip install selenium webdriver-manager
# Out:
# Collecting sqlalchemy
#   Downloading sqlalchemy-2.0.48-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Collecting greenlet>=1 (from sqlalchemy)
#   Downloading greenlet-3.3.2-cp311-cp311-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\pc\rssi_env\lib\site-packages (from sqlalchemy) (4.15.0)
# Downloading sqlalchemy-2.0.48-cp311-cp311-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.1 MB 196.9 kB/s eta 0:00:11
#    - -------------------------------------- 0.1/2.1 MB 297.7 kB/s eta 0:00:07
#    -- ------------------------------------- 0.1/2.1 MB 450.6 kB/s eta 0:00:05
#    -- ------------------------------------- 0.1/2.1 MB 448.2 kB/s eta 0:00:05
#    ---- ----------------------------------- 0.3/2.1 MB 749.3 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.3/2.1 MB 819.2 kB/s eta 0:00:03
#    ------ --------------------------------- 0.3/2.1 MB 771.5 kB/s eta 0:00:03
#    --------- ------------------------------ 0.5/2.1 MB 1.0 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.6/2.1 MB 1.2 MB/s eta 0:00:02
#    -------------- ------------------------- 0.8/2.1 MB 1.4 MB/s eta 0:00:01
#    -------------- ------------------------- 0.8/2.1 MB 1.4 MB/s eta 0:00:01
#    -------------- ------------------------- 0.8/2.1 MB 1.4 MB/s eta 0:00:01
#    -------------- ------------------------- 0.8/2.1 MB 1.4 MB/s eta 0:00:01
#    -------------- ------------------------- 0.8/2.1 MB 1.4 MB/s eta 0:00:01
#    -------------- ------------------------- 0.8/2.1 MB 1.0 MB/s eta 0:00:02
#    --------------- ------------------------ 0.8/2.1 MB 1.0 MB/s eta 0:00:02
#    --------------- ------------------------ 0.8/2.1 MB 964.5 kB/s eta 0:00:02
#    ---------------- ----------------------- 0.9/2.1 MB 971.3 kB/s eta 0:00:02
#    ---------------- ----------------------- 0.9/2.1 MB 927.9 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.9/2.1 MB 925.2 kB/s eta 0:00:02
#    ------------------- -------------------- 1.1/2.1 MB 1.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 1.2/2.1 MB 1.1 MB/s eta 0:00:01
#    -------------------------- ------------- 1.4/2.1 MB 1.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.1 MB 1.3 MB/s eta 0:00:01
#    -------------------------------- ------- 1.7/2.1 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 1.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.9/2.1 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 1.5 MB/s eta 0:00:00
# Downloading greenlet-3.3.2-cp311-cp311-win_amd64.whl (230 kB)
#    ---------------------------------------- 0.0/230.4 kB ? eta -:--:--
#    ------------------------ --------------- 143.4/230.4 kB 4.3 MB/s eta 0:00:01
#    ---------------------------------------  225.3/230.4 kB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 230.4/230.4 kB 2.4 MB/s eta 0:00:00
# Installing collected packages: greenlet, sqlalchemy
# Successfully installed greenlet-3.3.2 sqlalchemy-2.0.48
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: requests in c:\users\pc\rssi_env\lib\site-packages (2.32.5)
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\pc\rssi_env\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pc\rssi_env\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pc\rssi_env\lib\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pc\rssi_env\lib\site-packages (from requests) (2026.1.4)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.2.2
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting lxml
#   Downloading lxml-6.0.2-cp311-cp311-win_amd64.whl.metadata (3.7 kB)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4)
#   Downloading soupsieve-2.8.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\pc\rssi_env\lib\site-packages (from beautifulsoup4) (4.15.0)
# Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
#    ---------------------------------------- 0.0/107.7 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/107.7 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/107.7 kB ? eta -:--:--
#    ---------------------- ---------------- 61.4/107.7 kB 465.5 kB/s eta 0:00:01
#    -------------------------------------- 107.7/107.7 kB 691.4 kB/s eta 0:00:00
# Downloading lxml-6.0.2-cp311-cp311-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    - -------------------------------------- 0.1/4.0 MB 6.8 MB/s eta 0:00:01
#    - -------------------------------------- 0.2/4.0 MB 2.6 MB/s eta 0:00:02
#    --- ------------------------------------ 0.4/4.0 MB 3.0 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.5/4.0 MB 3.2 MB/s eta 0:00:02
#    ------- -------------------------------- 0.7/4.0 MB 3.6 MB/s eta 0:00:01
#    --------- ------------------------------ 1.0/4.0 MB 3.8 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.2/4.0 MB 3.9 MB/s eta 0:00:01
#    -------------- ------------------------- 1.4/4.0 MB 4.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.7/4.0 MB 4.3 MB/s eta 0:00:01
#    ------------------ --------------------- 1.8/4.0 MB 4.2 MB/s eta 0:00:01
#    -------------------- ------------------- 2.0/4.0 MB 4.2 MB/s eta 0:00:01
#    --------------------- ------------------ 2.2/4.0 MB 4.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.4/4.0 MB 4.3 MB/s eta 0:00:01
#    -------------------------- ------------- 2.6/4.0 MB 4.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.9/4.0 MB 4.3 MB/s eta 0:00:01
#    ------------------------------ --------- 3.1/4.0 MB 4.4 MB/s eta 0:00:01
#    -------------------------------- ------- 3.3/4.0 MB 4.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.6/4.0 MB 4.4 MB/s eta 0:00:01
#    ------------------------------------- -- 3.8/4.0 MB 4.5 MB/s eta 0:00:01
#    -------------------------------------- - 3.9/4.0 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------  4.0/4.0 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 4.2 MB/s eta 0:00:00
# Downloading soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Installing collected packages: soupsieve, lxml, beautifulsoup4
# Successfully installed beautifulsoup4-4.14.3 lxml-6.0.2 soupsieve-2.8.3
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting openpyxl
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting xlrd
#   Using cached xlrd-2.0.2-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached xlrd-2.0.2-py2.py3-none-any.whl (96 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: xlrd, et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5 xlrd-2.0.2
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting selenium
#   Using cached selenium-4.41.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting webdriver-manager
#   Using cached webdriver_manager-4.0.2-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: certifi>=2026.1.4 in c:\users\pc\rssi_env\lib\site-packages (from selenium) (2026.1.4)
# Collecting trio<1.0,>=0.31.0 (from selenium)
#   Using cached trio-0.33.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket<1.0,>=0.12.2 (from selenium)
#   Using cached trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in c:\users\pc\rssi_env\lib\site-packages (from selenium) (4.15.0)
# Requirement already satisfied: urllib3<3.0,>=2.6.3 in c:\users\pc\rssi_env\lib\site-packages (from urllib3[socks]<3.0,>=2.6.3->selenium) (2.6.3)
# Collecting websocket-client<2.0,>=1.8.0 (from selenium)
#   Downloading websocket_client-1.9.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: requests in c:\users\pc\rssi_env\lib\site-packages (from webdriver-manager) (2.32.5)
# Requirement already satisfied: python-dotenv in c:\users\pc\rssi_env\lib\site-packages (from webdriver-manager) (1.2.2)
# Requirement already satisfied: packaging in c:\users\pc\rssi_env\lib\site-packages (from webdriver-manager) (26.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\pc\rssi_env\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (25.4.0)
# Collecting sortedcontainers (from trio<1.0,>=0.31.0->selenium)
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: idna in c:\users\pc\rssi_env\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (3.11)
# Collecting outcome (from trio<1.0,>=0.31.0->selenium)
#   Using cached outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting sniffio>=1.3.0 (from trio<1.0,>=0.31.0->selenium)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting cffi>=1.14 (from trio<1.0,>=0.31.0->selenium)
#   Downloading cffi-2.0.0-cp311-cp311-win_amd64.whl.metadata (2.6 kB)
# Collecting wsproto>=0.14 (from trio-websocket<1.0,>=0.12.2->selenium)
#   Using cached wsproto-1.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pysocks!=1.5.7,<2.0,>=1.5.6 (from urllib3[socks]<3.0,>=2.6.3->selenium)
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\pc\rssi_env\lib\site-packages (from requests->webdriver-manager) (3.4.4)
# Collecting pycparser (from cffi>=1.14->trio<1.0,>=0.31.0->selenium)
#   Downloading pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting h11<1,>=0.16.0 (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Using cached selenium-4.41.0-py3-none-any.whl (9.5 MB)
# Using cached webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# Using cached trio-0.33.0-py3-none-any.whl (510 kB)
# Using cached trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading websocket_client-1.9.0-py3-none-any.whl (82 kB)
#    ---------------------------------------- 0.0/82.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/82.6 kB ? eta -:--:--
#    ------------------- -------------------- 41.0/82.6 kB 991.0 kB/s eta 0:00:01
#    ---------------------------------------- 82.6/82.6 kB 770.0 kB/s eta 0:00:00
# Downloading cffi-2.0.0-cp311-cp311-win_amd64.whl (182 kB)
#    ---------------------------------------- 0.0/182.8 kB ? eta -:--:--
#    -------------------- ------------------- 92.2/182.8 kB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 182.8/182.8 kB 2.2 MB/s eta 0:00:00
# Using cached outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached wsproto-1.3.2-py3-none-any.whl (24 kB)
# Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading pycparser-3.0-py3-none-any.whl (48 kB)
#    ---------------------------------------- 0.0/48.2 kB ? eta -:--:--
#    ---------------------------------------- 48.2/48.2 kB 1.2 MB/s eta 0:00:00
# Installing collected packages: sortedcontainers, websocket-client, sniffio, pysocks, pycparser, outcome, h11, wsproto, webdriver-manager, cffi, trio, trio-websocket, selenium
# Successfully installed cffi-2.0.0 h11-0.16.0 outcome-1.3.0.post0 pycparser-3.0 pysocks-1.7.1 selenium-4.41.0 sniffio-1.3.1 sortedcontainers-2.4.0 trio-0.33.0 trio-websocket-0.12.2 webdriver-manager-4.0.2 websocket-client-1.9.0 wsproto-1.3.2
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 1.1 Why Databases? Understanding the Foundation
#
# Imagine you have a spreadsheet with 1 million rows of customer data. Every time you want to find customers from Cairo, you have to scan through all rows. Now imagine 10 people trying to update this spreadsheet simultaneously. Chaos, right?
#
# **This is why we need databases:**
#
# - 🚀 **Speed:** Databases use indexes (like a book's index) to find data instantly
# - 🔗 **Relationships:** Instead of repeating customer info in every order, link them with IDs
# - ✅ **Integrity:** Ensure data follows rules (e.g., email must be unique, price > 0)
# - 👥 **Concurrency:** Multiple users can access/modify data safely
#
# ### <span style="color:blue">ACID Properties</span>
#
# | Property | Description |
# |---|---|
# | **Atomicity** | All changes happen or none happen (no half-updates) |
# | **Consistency** | Data always follows defined rules |
# | **Isolation** | Concurrent transactions don't interfere |
# | **Durability** | Once saved, data survives crashes |

# %% [markdown]
# ## 1.2 Database Fundamentals with Real Example
#
# **Scenario:** You're building a library management system.
#
# ### ❌ Bad Design (CSV approach):
# ```
# book_id, book_title, author_name, author_email, borrower_name, borrower_email, due_date
# 1, "Python 101", "John Doe", "john@email.com", "Ahmed Ali", "ahmed@email.com", "2024-03-15"
# 2, "SQL Basics", "John Doe", "john@email.com", "Sara Ahmed", "sara@email.com", "2024-03-20"
# ```
#
# **Problems:**
# - Author info repeated (what if John's email changes?)
# - Can't track multiple borrowings of same book
# - Hard to find "all books by John Doe"
#
# ### ✅ Good Design (Relational):
#
# **Authors Table:**
# ```
# author_id | name      | email
# 1         | John Doe  | john@email.com
# ```
#
# **Books Table:**
# ```
# book_id | title        | author_id (FK)
# 1       | Python 101   | 1
# 2       | SQL Basics   | 1
# ```
#
# **Members Table:**
# ```
# member_id | name       | email
# 101       | Ahmed Ali  | ahmed@email.com
# ```
#
# **Borrowings Table:**
# ```
# borrow_id | book_id (FK) | member_id (FK) | borrow_date | due_date
# 1         | 1            | 101            | 2024-03-01  | 2024-03-15
# ```
#
# ### Key Concepts:
# - **`Primary Key (PK)`**: Unique identifier (`author_id`, `book_id`)
# - **`Foreign Key (FK)`**: Links to another table's PK
# - **Normalization**: Avoid data duplication

# %% [markdown]
# ## 1.3 Exercise 1: Building Our Library Database
#
# We'll create a complete SQLite library database with 4 related tables and sample data.

# %%
import sqlite3
import pandas as pd
from datetime import datetime, timedelta
import random

# Create database connection (creates 'library.db' file if it doesn't exist)
# Close a stale connection if this cell is re-run in the same kernel.
if 'conn' in globals():
    try:
        conn.close()
    except Exception:
        pass

conn = sqlite3.connect('library.db', timeout=30)
conn.execute('PRAGMA busy_timeout = 30000')
conn.execute('PRAGMA journal_mode = WAL')
cursor = conn.cursor()

# ─────────────────────────────────────────────
# Step 1: Create Authors table
# ─────────────────────────────────────────────
cursor.execute(
    '''
CREATE TABLE IF NOT EXISTS authors (
    author_id INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT NOT NULL,
    email TEXT UNIQUE,
    country TEXT,
    birth_year INTEGER
)
'''
)

# ─────────────────────────────────────────────
# Step 2: Create Books table
# Note: FOREIGN KEY links books to their author
# ─────────────────────────────────────────────
cursor.execute(
    '''
CREATE TABLE IF NOT EXISTS books (
    book_id INTEGER PRIMARY KEY AUTOINCREMENT,
    title TEXT NOT NULL,
    author_id INTEGER NOT NULL,
    isbn TEXT UNIQUE,
    publication_year INTEGER,
    genre TEXT,
    copies_available INTEGER DEFAULT 1 CHECK(copies_available >= 0),
    FOREIGN KEY (author_id) REFERENCES authors(author_id)
)
'''
)

# ─────────────────────────────────────────────
# Step 3: Create Members table
# Note: membership_type is restricted via CHECK constraint
# ─────────────────────────────────────────────
cursor.execute(
    '''
CREATE TABLE IF NOT EXISTS members (
    member_id INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT NOT NULL,
    email TEXT UNIQUE NOT NULL,
    phone TEXT,
    join_date DATE DEFAULT CURRENT_DATE,
    membership_type TEXT CHECK(membership_type IN ('student', 'faculty', 'public'))
)
'''
)

# ─────────────────────────────────────────────
# Step 4: Create Borrowings table
# Note: Links both books and members via FOREIGN KEYs
# ─────────────────────────────────────────────
cursor.execute(
    '''
CREATE TABLE IF NOT EXISTS borrowings (
    borrow_id INTEGER PRIMARY KEY AUTOINCREMENT,
    book_id INTEGER NOT NULL,
    member_id INTEGER NOT NULL,
    borrow_date DATE NOT NULL,
    due_date DATE NOT NULL,
    return_date DATE,
    fine_amount REAL DEFAULT 0,
    FOREIGN KEY (book_id) REFERENCES books(book_id),
    FOREIGN KEY (member_id) REFERENCES members(member_id)
)
'''
)

# ─────────────────────────────────────────────
# Insert sample authors (famous Egyptian authors)
# ─────────────────────────────────────────────
authors_data = [
    ('Naguib Mahfouz', 'mahfouz@literature.eg', 'Egypt', 1911),
    ('Taha Hussein', 'taha@literature.eg', 'Egypt', 1889),
    ('Nawal El Saadawi', 'nawal@literature.eg', 'Egypt', 1931),
    ('Alaa Al aswany', 'alaa@literature.eg', 'Egypt', 1957),
    ('Ahdaf Soueif', 'ahdaf@literature.eg', 'Egypt', 1950),
]

cursor.executemany(
    '''
    INSERT INTO authors (name, email, country, birth_year)
    VALUES (?, ?, ?, ?)
''',
    authors_data,
)

# ─────────────────────────────────────────────
# Insert sample books
# author_id references the authors table above
# ─────────────────────────────────────────────
books_data = [
    ('Cairo Trilogy', 1, '978-0307947109', 1956, 'Fiction', 3),
    ('The Days', 2, '978-9774160011', 1929, 'Biography', 2),
    ('Woman at Point Zero', 3, '978-1848134171', 1975, 'Fiction', 2),
    ('The Yacoubian Building', 4, '978-0060878139', 2002, 'Fiction', 4),
    ('The Map of Love', 5, '978-0385720038', 1999, 'Fiction', 2),
    ('Palace Walk', 1, '978-0307947093', 1956, 'Fiction', 2),
    ('Children of Gebelawi', 1, '978-0894108723', 1959, 'Fiction', 1),
    ('God Dies by the Nile', 3, '978-1848134188', 1974, 'Fiction', 3),
]

cursor.executemany(
    '''
    INSERT INTO books (title, author_id, isbn, publication_year, genre, copies_available)
    VALUES (?, ?, ?, ?, ?, ?)
''',
    books_data,
)

# ─────────────────────────────────────────────
# Insert sample members
# ─────────────────────────────────────────────
members_data = [
    ('Ahmed Hassan', 'ahmed.hassan@university.edu', '0101234567', 'student'),
    ('Fatima Ali', 'fatima.ali@university.edu', '0109876543', 'student'),
    ('Mohamed Ibrahim', 'mohamed.ibrahim@university.edu', '0105555555', 'faculty'),
    ('Layla Mahmoud', 'layla.mahmoud@gmail.com', '0102222222', 'public'),
    ('Omar Khaled', 'omar.khaled@university.edu', '0103333333', 'student'),
]

cursor.executemany(
    '''
    INSERT INTO members (name, email, phone, membership_type)
    VALUES (?, ?, ?, ?)
''',
    members_data,
)

# ─────────────────────────────────────────────
# Insert sample borrowings (randomly generated)
# Fine = 2 EGP per day overdue
# ─────────────────────────────────────────────
borrowings_data = []
base_date = datetime(2024, 2, 1)

for i in range(20):
    book_id = random.randint(1, 8)
    member_id = random.randint(1, 5)
    days_ago = random.randint(1, 60)
    borrow_date = (base_date - timedelta(days=days_ago)).strftime('%Y-%m-%d')
    due_date = (base_date - timedelta(days=days_ago) + timedelta(days=14)).strftime(
        '%Y-%m-%d'
    )

    # Some books returned (70%), some still borrowed (30%)
    if random.random() > 0.3:  # 70% returned
        return_date = (
            base_date - timedelta(days=days_ago) + timedelta(days=random.randint(1, 20))
        ).strftime('%Y-%m-%d')
        # Calculate fine if overdue
        due = datetime.strptime(due_date, '%Y-%m-%d')
        returned = datetime.strptime(return_date, '%Y-%m-%d')
        days_late = max(0, (returned - due).days)
        fine = days_late * 2.0  # 2 EGP per day
    else:
        return_date = None
        fine = 0

    borrowings_data.append(
        (book_id, member_id, borrow_date, due_date, return_date, fine)
    )

cursor.executemany(
    '''
    INSERT INTO borrowings (book_id, member_id, borrow_date, due_date, return_date, fine_amount)
    VALUES (?, ?, ?, ?, ?, ?)
''',
    borrowings_data,
)

conn.commit()
print("✅ Library database created successfully!")
print(f"  - {len(authors_data)} authors")
print(f"  - {len(books_data)} books")
print(f"  - {len(members_data)} members")
print(f"  - {len(borrowings_data)} borrowings")
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# Cell In[3], line 101
#      90 # ─────────────────────────────────────────────
#      91 # Insert sample authors (famous Egyptian authors)
#      92 # ─────────────────────────────────────────────
#      93 authors_data = [
#      94     ('Naguib Mahfouz', 'mahfouz@literature.eg', 'Egypt', 1911),
#      95     ('Taha Hussein', 'taha@literature.eg', 'Egypt', 1889),
#    (...)     98     ('Ahdaf Soueif', 'ahdaf@literature.eg', 'Egypt', 1950),
#      99 ]
# --> 101 cursor.executemany(
#     102     '''
#     103     INSERT INTO authors (name, email, country, birth_year)
#     104     VALUES (?, ?, ?, ?)
#     105 ''',
#     106     authors_data,
#     107 )
#     109 # ─────────────────────────────────────────────
#     110 # Insert sample books
#     111 # author_id references the authors table above
#     112 # ─────────────────────────────────────────────
#     113 books_data = [
#     114     ('Cairo Trilogy', 1, '978-0307947109', 1956, 'Fiction', 3),
#     115     ('The Days', 2, '978-9774160011', 1929, 'Biography', 2),
#    (...)    121     ('God Dies by the Nile', 3, '978-1848134188', 1974, 'Fiction', 3),
#     122 ]
#
# IntegrityError: UNIQUE constraint failed: authors.email

# %% [markdown]
# ### What just happened?
# - ✅ Created **4 related tables**
# - ✅ Used **`PRIMARY KEY`** for unique identifiers
# - ✅ Used **`FOREIGN KEY`** to link tables
# - ✅ Added constraints (`CHECK`, `UNIQUE`, `NOT NULL`)
# - ✅ Inserted realistic sample data

# %% [markdown]
# ## 1.4 SQL Queries: from Basic to Advanced
#
# ### Level 1: Basic `select`

# %%
# Query 1: View all books (LIMIT to first 5 rows)
query = "select * from books LIMIT 5"
df = pd.read_sql_query(query, conn)
print("All Books:")
print(df)
# Out:
# All Books:
#    book_id                   title  author_id            isbn  \
# 0        1           Cairo Trilogy          1  978-0307947109
# 1        2                The Days          2  978-9774160011
# 2        3     Woman at Point Zero          3  978-1848134171
# 3        4  The Yacoubian Building          4  978-0060878139
# 4        5         The Map of Love          5  978-0385720038
#
#    publication_year      genre  copies_available
# 0              1956    Fiction                 3
# 1              1929  Biography                 2
# 2              1975    Fiction                 2
# 3              2002    Fiction                 4
# 4              1999    Fiction                 2

# %%
# Query 2: select specific columns only (avoid select * in production)
query = "select title, genre, publication_year from books"
df = pd.read_sql_query(query, conn)
print("\nBook Titles and Genres:")
print(df)
# Out:
# Book Titles and Genres:
#                     title      genre  publication_year
# 0           Cairo Trilogy    Fiction              1956
# 1                The Days  Biography              1929
# 2     Woman at Point Zero    Fiction              1975
# 3  The Yacoubian Building    Fiction              2002
# 4         The Map of Love    Fiction              1999
# 5             Palace Walk    Fiction              1956
# 6    Children of Gebelawi    Fiction              1959
# 7    God Dies by the Nile    Fiction              1974
# 8              New Book 1    Fiction              2024
# 9              New Book 2  Biography              2024

# %%
# Query 3: Calculated columns using as (creates a virtual/derived column)
query = """
select
    title,
    copies_available,
    copies_available * 50 as inventory_value_egp
from books
"""
df = pd.read_sql_query(query, conn)
print("\nInventory Value:")
print(df)
# Out:
# Inventory Value:
#                     title  copies_available  inventory_value_egp
# 0           Cairo Trilogy                 3                  150
# 1                The Days                 2                  100
# 2     Woman at Point Zero                 2                  100
# 3  The Yacoubian Building                 4                  200
# 4         The Map of Love                 2                  100
# 5             Palace Walk                 2                  100
# 6    Children of Gebelawi                 1                   50
# 7    God Dies by the Nile                 3                  150
# 8              New Book 1                 3                  150
# 9              New Book 2                 2                  100

# %% [markdown]
# #### Explanation:
# - **`*`** means "all columns"
# - You can select specific columns by name
# - You can create new columns with calculations using **`as`**

# %% [markdown]
# ### Level 2: Filtering with `where`

# %%
# Query 1: Books by specific author (filter by author_id)
query = """
select title, publication_year
from books
where author_id = 1
"""
df = pd.read_sql_query(query, conn)
print("Books by Naguib Mahfouz:")
print(df)
# Out:
# Books by Naguib Mahfouz:
#                   title  publication_year
# 0         Cairo Trilogy              1956
# 1           Palace Walk              1956
# 2  Children of Gebelawi              1959
# 3            New Book 1              2024

# %%
# Query 2: Multiple conditions with AND (all conditions must be true)
query = """
select title, genre, publication_year
from books
where genre = 'Fiction'
  AND publication_year > 1950
  AND copies_available > 1
"""
df = pd.read_sql_query(query, conn)
print("\nModern Fiction with Multiple Copies:")
print(df)
# Out:
# Modern Fiction with Multiple Copies:
#                     title    genre  publication_year
# 0           Cairo Trilogy  Fiction              1956
# 1     Woman at Point Zero  Fiction              1975
# 2  The Yacoubian Building  Fiction              2002
# 3         The Map of Love  Fiction              1999
# 4             Palace Walk  Fiction              1956
# 5    God Dies by the Nile  Fiction              1974
# 6              New Book 1  Fiction              2024

# %%
# Query 3: Pattern matching with LIKE
# '%' = any number of characters, '_' = exactly one character
query = """
select name, email
from members
where email LIKE '%@university.edu'
"""
df = pd.read_sql_query(query, conn)
print("\nUniversity Members:")
print(df)
# Out:
# University Members:
#               name                           email
# 0     Ahmed Hassan     ahmed.hassan@university.edu
# 1       Fatima Ali       fatima.ali@university.edu
# 2  Mohamed Ibrahim  mohamed.ibrahim@university.edu
# 3      Omar Khaled      omar.khaled@university.edu

# %% [markdown]
# #### `LIKE` Patterns:
# | Pattern | Meaning |
# |---|---|
# | **`%`** | Any number of characters |
# | **`_`** | Exactly one character |
# | `LIKE 'A%'` | Names starting with A |
# | `LIKE '%@gmail.com'` | Gmail users |

# %%
# Query 4: Using IN for multiple values (cleaner than multiple OR conditions)
query = """
select name, membership_type
from members
where membership_type IN ('student', 'faculty')
"""
df = pd.read_sql_query(query, conn)
print("\nAcademic Members:")
print(df)
# Out:
# Academic Members:
#               name membership_type
# 0     Ahmed Hassan         student
# 1       Fatima Ali         student
# 2  Mohamed Ibrahim         faculty
# 3      Omar Khaled         student

# %%
# Query 5: NULL handling - find books not yet returned
# Note: Use IS NULL / IS NOT NULL (never = NULL)
query = """
select
    b.book_id,
    bk.title,
    b.borrow_date,
    b.due_date,
    b.return_date
from borrowings b
join books bk ON b.book_id = bk.book_id
where b.return_date IS NULL
"""
df = pd.read_sql_query(query, conn)
print("\nCurrently Borrowed Books:")
print(df)
# Out:
# Currently Borrowed Books:
#    book_id                   title borrow_date    due_date return_date
# 0        5         The Map of Love  2023-12-27  2024-01-10        None
# 1        7    Children of Gebelawi  2024-01-31  2024-02-14        None
# 2        7    Children of Gebelawi  2024-01-24  2024-02-07        None
# 3        4  The Yacoubian Building  2024-01-27  2024-02-10        None

# %% [markdown]
# #### Understanding `NULL`:
# - `NULL` means "no value" or "unknown"
# - Use **`IS NULL`** or **`IS NOT NULL`** (NOT `= NULL`)
# - `NULL` is different from `0` or empty string `''`

# %% [markdown]
# ### Level 3: Aggregations

# %%
# Query 1: count total books
query = "select count(*) as total_books from books"
df = pd.read_sql_query(query, conn)
print("Total Books:", df['total_books'][0])
# Out:
# Total Books: 10

# %%
# Query 2: Multiple aggregations in one query
query = """
select
    count(*) as total_borrowings,
    count(return_date) as returned_count,
    count(*) - count(return_date) as still_borrowed,
    sum(fine_amount) as total_fines,
    AVG(fine_amount) as avg_fine,
    MAX(fine_amount) as highest_fine
from borrowings
"""
df = pd.read_sql_query(query, conn)
print("\nBorrowing Statistics:")
print(df.T)  # Transpose for better display
# Out:
# Borrowing Statistics:
#                      0
# total_borrowings  20.0
# returned_count    16.0
# still_borrowed     4.0
# total_fines       32.0
# avg_fine           1.6
# highest_fine      12.0

# %% [markdown]
# #### Aggregation Functions:
# | Function | Description |
# |---|---|
# | **`count(*)`** | count all rows |
# | **`count(column)`** | count non-NULL values |
# | **`sum(column)`** | Total of values |
# | **`AVG(column)`** | Average |
# | **`MIN(column)`** | Minimum |
# | **`MAX(column)`** | Maximum |

# %%
# Query 3: group BY - groups rows sharing a value and applies aggregation
query = """
select
    genre,
    count(*) as book_count,
    AVG(publication_year) as avg_year,
    sum(copies_available) as total_copies
from books
group BY genre
order BY book_count desc
"""
df = pd.read_sql_query(query, conn)
print("\nBooks by Genre:")
print(df)
# Out:
# Books by Genre:
#        genre  book_count  avg_year  total_copies
# 0    Fiction           8  1980.625            20
# 1  Biography           2  1976.500             4

# %% [markdown]
# #### Understanding `group BY`:
#
# ```
# Before group BY:          After group BY:
# book_id  genre           genre      count(*)
# 1        Fiction         Fiction    7
# 2        Biography  -->  Biography  1
# 3        Fiction
# 4        Fiction
# ...
# ```

# %%
# Query 4: HAVING - filter AFTER grouping (where filters BEFORE grouping)
query = """
select
    member_id,
    count(*) as borrow_count,
    sum(fine_amount) as total_fines
from borrowings
group BY member_id
HAVING borrow_count > 3
order BY total_fines desc
"""
df = pd.read_sql_query(query, conn)
print("\nFrequent Borrowers (>3 borrowings):")
print(df)
# Out:
# Frequent Borrowers (>3 borrowings):
#    member_id  borrow_count  total_fines
# 0          2             8         20.0
# 1          3             6         12.0

# %% [markdown]
# #### <span style="color:red">where vs HAVING:</span>
# - **`where`** filters rows **BEFORE** grouping
# - **`HAVING`** filters groups **AFTER** grouping
#
# ```sql
# select genre, count(*)
# from books
# where publication_year > 1950  -- Filter individual books first
# group BY genre
# HAVING count(*) > 2             -- Then filter the groups
# ```

# %% [markdown]
# ### Level 4: JOINs - Connecting the Dots
#
# #### Visual Understanding of JOINs:
#
# ```
# Authors Table:          Books Table:
# author_id | name        book_id | title           | author_id
# 1         | Mahfouz     1       | Cairo Trilogy   | 1
# 2         | Hussein     2       | The Days        | 2
# 3         | Saadawi     3       | Woman at Zero   | 3
#                         4       | Palace Walk     | 1
# ```
#
# **`inner join`** (only matching rows):
# ```
# Result:
# author_id | name    | book_id | title
# 1         | Mahfouz | 1       | Cairo Trilogy
# 1         | Mahfouz | 4       | Palace Walk
# 2         | Hussein | 2       | The Days
# 3         | Saadawi | 3       | Woman at Zero
# ```

# %%
# Query 1: inner join - Books with their authors
# Only returns books that HAVE a matching author (and vice versa)
query = """
select
    b.title,
    b.publication_year,
    a.name as author_name,
    a.country
from books b
inner join authors a ON b.author_id = a.author_id
order BY b.publication_year
"""
df = pd.read_sql_query(query, conn)
print("Books with Authors:")
print(df)
# Out:
# Books with Authors:
#                     title  publication_year       author_name country
# 0                The Days              1929      Taha Hussein   Egypt
# 1           Cairo Trilogy              1956    Naguib Mahfouz   Egypt
# 2             Palace Walk              1956    Naguib Mahfouz   Egypt
# 3    Children of Gebelawi              1959    Naguib Mahfouz   Egypt
# 4    God Dies by the Nile              1974  Nawal El Saadawi   Egypt
# 5     Woman at Point Zero              1975  Nawal El Saadawi   Egypt
# 6         The Map of Love              1999      Ahdaf Soueif   Egypt
# 7  The Yacoubian Building              2002    Alaa Al Aswany   Egypt
# 8              New Book 1              2024    Naguib Mahfouz   Egypt
# 9              New Book 2              2024      Taha Hussein   Egypt

# %% [markdown]
# #### Understanding the join:
# - **`books b`** — give books an alias `'b'`
# - **`inner join authors a`** — join with authors (alias `'a'`)
# - **`ON b.author_id = a.author_id`** — match where IDs are equal
# - Only returns rows where there's a match in **BOTH** tables

# %%
# Query 2: Three-table join - Complete borrowing info with CASE statement
# CASE is SQL's if-else for conditional logic
query = """
select
    m.name as borrower_name,
    m.membership_type,
    b.title as book_title,
    a.name as author_name,
    br.borrow_date,
    br.due_date,
    br.return_date,
    CASE
        WHEN br.return_date IS NULL THEN 'Still Borrowed'
        WHEN br.return_date <= br.due_date THEN 'Returned On Time'
        ELSE 'Returned Late'
    END as status,
    br.fine_amount
from borrowings br
inner join members m ON br.member_id = m.member_id
inner join books b ON br.book_id = b.book_id
inner join authors a ON b.author_id = a.author_id
where br.fine_amount > 0
order BY br.fine_amount desc
"""
df = pd.read_sql_query(query, conn)
print("\nBorrowings with Fines:")
print(df.head(10))
# Out:
# Borrowings with Fines:
#      borrower_name membership_type            book_title       author_name  \
# 0       Fatima Ali         student              The Days      Taha Hussein
# 1  Mohamed Ibrahim         faculty       The Map of Love      Ahdaf Soueif
# 2       Fatima Ali         student  God Dies by the Nile  Nawal El Saadawi
# 3       Fatima Ali         student   Woman at Point Zero  Nawal El Saadawi
#
#   borrow_date    due_date return_date         status  fine_amount
# 0  2023-12-06  2023-12-20  2023-12-26  Returned Late         12.0
# 1  2023-12-22  2024-01-05  2024-01-11  Returned Late         12.0
# 2  2024-01-22  2024-02-05  2024-02-08  Returned Late          6.0
# 3  2024-01-18  2024-02-01  2024-02-02  Returned Late          2.0

# %% [markdown]
# #### <span style="color:blue">CASE Statement</span> (SQL's if-else):
# ```sql
# CASE
#     WHEN condition1 THEN result1
#     WHEN condition2 THEN result2
#     ELSE default_result
# END as column_name
# ```

# %% [markdown]
# #### `LEFT join` (all from left table, matching from right):
# ```
# Authors Table (LEFT):   Books Table (RIGHT):
# author_id | name        book_id | author_id
# 1         | Mahfouz     1       | 1
# 2         | Hussein     4       | 1
# 3         | Saadawi
# 4         | No Books
#
# Result with LEFT join:
# author_id | name      | book_id | title
# 1         | Mahfouz   | 1       | Cairo Trilogy
# 1         | Mahfouz   | 4       | Palace Walk
# 2         | Hussein   | NULL    | NULL    ← no books but still appears!
# 3         | Saadawi   | NULL    | NULL
# 4         | No Books  | NULL    | NULL
# ```

# %%
# Query 3: LEFT join - Find authors with no books in the library
# LEFT join ensures ALL authors appear, even those with 0 books
query = """
select
    a.name,
    a.email,
    count(b.book_id) as book_count
from authors a
LEFT join books b ON a.author_id = b.author_id
group BY a.author_id, a.name, a.email
HAVING book_count = 0
"""
df = pd.read_sql_query(query, conn)
print("\nAuthors Without Books:")
print(df)
# Out:
# Authors Without Books:
# Empty DataFrame
# Columns: [name, email, book_count]
# Index: []

# %%
# Query 4: LEFT join - Members who never borrowed (activity report)
query = """
select
    m.name,
    m.email,
    m.membership_type,
    m.join_date,
    count(br.borrow_id) as borrow_count
from members m
LEFT join borrowings br ON m.member_id = br.member_id
group BY m.member_id, m.name, m.email, m.membership_type, m.join_date
order BY borrow_count
"""
df = pd.read_sql_query(query, conn)
print("\nMember Activity:")
print(df)
# Out:
# Member Activity:
#               name                           email membership_type  \
# 0    Layla Mahmoud         layla.mahmoud@gmail.com          public
# 1     Ahmed Hassan     ahmed.hassan@university.edu         student
# 2      Omar Khaled      omar.khaled@university.edu         student
# 3  Mohamed Ibrahim  mohamed.ibrahim@university.edu         faculty
# 4       Fatima Ali       fatima.ali@university.edu         student
#
#     join_date  borrow_count
# 0  2026-03-05             0
# 1  2026-03-05             3
# 2  2026-03-05             3
# 3  2026-03-05             6
# 4  2026-03-05             8

# %% [markdown]
# #### Why `LEFT join`?
# - Shows **ALL** authors/members, even if they have no books/borrowings
# - Useful for **finding gaps** (who hasn't participated?)

# %% [markdown]
# ### Level 5: Advanced Queries

# %%
# Query 1: Subquery in where
# inner query runs first → finds author_ids → outer query uses those IDs
query = """
select title, publication_year
from books
where author_id IN (
    select author_id
    from authors
    where country = 'Egypt' AND birth_year < 1950
)
order BY publication_year
"""
df = pd.read_sql_query(query, conn)
print("Books by Egyptian authors born before 1950:")
print(df)
# Out:
# Books by Egyptian authors born before 1950:
#                   title  publication_year
# 0              The Days              1929
# 1         Cairo Trilogy              1956
# 2           Palace Walk              1956
# 3  Children of Gebelawi              1959
# 4  God Dies by the Nile              1974
# 5   Woman at Point Zero              1975
# 6            New Book 1              2024
# 7            New Book 2              2024

# %%
# Query 2: Subquery in select
# Compares each book's year to the overall average publication year
query = """
select
    b.title,
    b.publication_year,
    (select AVG(publication_year) from books) as avg_pub_year,
    b.publication_year - (select AVG(publication_year) from books) as year_diff
from books b
order BY year_diff desc
"""
df = pd.read_sql_query(query, conn)
print("\nBooks compared to average publication year:")
print(df)
# Out:
# Books compared to average publication year:
#                     title  publication_year  avg_pub_year  year_diff
# 0              New Book 1              2024        1979.8       44.2
# 1              New Book 2              2024        1979.8       44.2
# 2  The Yacoubian Building              2002        1979.8       22.2
# 3         The Map of Love              1999        1979.8       19.2
# 4     Woman at Point Zero              1975        1979.8       -4.8
# 5    God Dies by the Nile              1974        1979.8       -5.8
# 6    Children of Gebelawi              1959        1979.8      -20.8
# 7           Cairo Trilogy              1956        1979.8      -23.8
# 8             Palace Walk              1956        1979.8      -23.8
# 9                The Days              1929        1979.8      -50.8

# %%
# Query 3: Common Table Expression (CTE) - Cleaner than nested subqueries!
# WITH clause creates named temporary result sets, used in the final select
query = """
WITH author_stats as (
    -- Step 1: Calculate book counts and avg year per author
    select
        a.author_id,
        a.name,
        count(b.book_id) as book_count,
        AVG(b.publication_year) as avg_year
    from authors a
    LEFT join books b ON a.author_id = b.author_id
    group BY a.author_id, a.name
),
borrowing_stats as (
    -- Step 2: Calculate total borrowings per author
    select
        b.author_id,
        count(br.borrow_id) as total_borrowings
    from books b
    LEFT join borrowings br ON b.book_id = br.book_id
    group BY b.author_id
)
-- Step 3: Combine both CTEs into final result
select
    ast.name,
    ast.book_count,
    ast.avg_year,
    COALESCE(bs.total_borrowings, 0) as popularity  -- COALESCE replaces NULL with 0
from author_stats ast
LEFT join borrowing_stats bs ON ast.author_id = bs.author_id
order BY popularity desc
"""
df = pd.read_sql_query(query, conn)
print("\nAuthor Popularity Analysis:")
print(df)
# Out:
# Author Popularity Analysis:
#                name  book_count  avg_year  popularity
# 0    Naguib Mahfouz           4   1973.75           9
# 1  Nawal El Saadawi           2   1974.50           5
# 2      Ahdaf Soueif           1   1999.00           3
# 3      Taha Hussein           2   1976.50           2
# 4    Alaa Al Aswany           1   2002.00           1

# %% [markdown]
# #### <span style="color:blue">Why CTEs are Better than Subqueries:</span>
#
# ❌ **Subquery (messy):**
# ```sql
# select ...
# from (select ... from (select ... from table))
# ```
#
# ✅ **CTE (clean and readable):**
# ```sql
# WITH step1 as (select ...),
#      step2 as (select ...)
# select ... from step1 join step2
# ```

# %% [markdown]
# ## 1.5 Production Best Practices: SQLAlchemy
#
# ### <span style="color:blue">Why SQLAlchemy?</span>
# - Works with **multiple databases** (SQLite, PostgreSQL, MySQL)
# - Automatic **connection pooling**
# - **Safer** (prevents SQL injection)
# - Better **error handling**

# %%
from sqlalchemy import create_engine, text
import pandas as pd

# Create engine (works with any database just by changing the connection string)
# SQLite:     'sqlite:///library.db'
# PostgreSQL: 'postgresql://user:pass@host/dbname'
# MySQL:      'mysql+pymysql://user:pass@host/dbname'
engine = create_engine('sqlite:///library.db')

# ─────────────────────────────────────────────
# Method 1: Using context manager (auto-cleanup, preferred approach)
# The 'with' block automatically closes connection when done
# ─────────────────────────────────────────────
with engine.connect() as conn:
    query = text(
        "select * from books where genre = :genre"
    )  # :genre is a named parameter
    df = pd.read_sql(query, conn, params={'genre': 'Fiction'})
    print("Fiction books:")
    print(df)
# Out:
# Fiction books:
#    book_id                   title  author_id            isbn  \
# 0        1           Cairo Trilogy          1  978-0307947109
# 1        3     Woman at Point Zero          3  978-1848134171
# 2        4  The Yacoubian Building          4  978-0060878139
# 3        5         The Map of Love          5  978-0385720038
# 4        6             Palace Walk          1  978-0307947093
# 5        7    Children of Gebelawi          1  978-0894108723
# 6        8    God Dies by the Nile          3  978-1848134188
# 7        9              New Book 1          1  978-1234567890
#
#    publication_year    genre  copies_available
# 0              1956  Fiction                 3
# 1              1975  Fiction                 2
# 2              2002  Fiction                 4
# 3              1999  Fiction                 2
# 4              1956  Fiction                 2
# 5              1959  Fiction                 1
# 6              1974  Fiction                 3
# 7              2024  Fiction                 3

# %%
# ─────────────────────────────────────────────
# Method 2: Parameterized queries (prevents SQL injection!)
# ─────────────────────────────────────────────
with engine.connect() as conn:
    # ❌ BAD - vulnerable to SQL injection:
    # query = f"select * from members where email = '{user_input}'"

    # ✅ GOOD - safe parameterized query:
    query = text(
        """
        select * from borrowings
        where member_id = :member_id
          AND fine_amount > :min_fine
    """
    )
    df = pd.read_sql(query, conn, params={'member_id': 1, 'min_fine': 5.0})
    print("Borrowings with fine > 5 EGP for member 1:")
    print(df)
# Out:
# Borrowings with fine > 5 EGP for member 1:
# Empty DataFrame
# Columns: [borrow_id, book_id, member_id, borrow_date, due_date, return_date, fine_amount]
# Index: []

# %%
# ─────────────────────────────────────────────
# Method 3: Writing DataFrames directly to database
# if_exists options: 'replace' (drop & recreate), 'append' (add rows), 'fail' (raise error)
# ─────────────────────────────────────────────
new_books_df = pd.DataFrame(
    {
        'title': ['New Book 1', 'New Book 2'],
        'author_id': [1, 2],
        'isbn': ['978-1234567890', '978-0987654321'],
        'publication_year': [2024, 2024],
        'genre': ['Fiction', 'Biography'],
        'copies_available': [3, 2],
    }
)

new_books_df.to_sql(
    'books',
    engine,
    if_exists='append',  # Append to existing table
    index=False,  # Don't write DataFrame index as a column
)
print("New books added successfully!")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\PC\rssi_env\Lib\site-packages\sqlalchemy\engine\base.py:1936, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1935     if not evt_handled:
# -> 1936         self.dialect.do_executemany(
#    1937             cursor,
#    1938             str_statement,
#    1939             effective_parameters,
#    1940             context,
#    1941         )
#    1942 elif not effective_parameters and context.no_parameters:
#
# File c:\Users\PC\rssi_env\Lib\site-packages\sqlalchemy\engine\default.py:949, in DefaultDialect.do_executemany(self, cursor, statement, parameters, context)
#     948 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 949     cursor.executemany(statement, parameters)
#
# OperationalError: database is locked
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# File c:\Users\PC\rssi_env\Lib\site-packages\pandas\io\sql.py:1679, in SQLDatabase.execute(self, sql, params)
#    1678 try:
# -> 1679     return execute_function(sql, *args)
#    1680 except SQLAlchemyError as exc:
#
# File c:\Users\PC\rssi_env\Lib\site-packages\sqlalchemy\engine\base.py:1419, in Connection.execute(self, statement, parameters, execution_options)
#    1418 else:
# -> 1419     return meth(
#    1420         self,
#    1421         distilled_parameters,
#    1422         execution_options or NO_OPTIONS,
#    1423     )
#
# File c:\Users\PC\rssi_env\Lib\site-packages\sqlalchemy\sql\elements.py:527, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     526         assert isinstance(self, Executable)
# --> 527     return connection._execute_clauseelement(
#     528         self, distilled_params, execution_options
#     529     )
#     530 else:
#
# File c:\Users\PC\rssi_env\Lib\site-packages\sqlalchemy\engine\base.py:1641, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1633 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1634     dialect=dialect,
#    1635     compiled_cache=compiled_cache,
#    (...)   1639     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1640 )
# -> 1641 ret = self._execute_context(
#    1642     dialect,
#    1643     dialect.execution_ctx_cls._init_compiled,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     execution_options,
#    1647     compiled_sql,
#    1648     distilled_parameters,
#    1649     elem,
#    1650     extracted_params,
#    1651     cache_hit=cache_hit,
#    1652 )
#    1653 if has_events:
#
# File c:\Users\PC\rssi_env\Lib\site-packages\sqlalchemy\engine\base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File c:\Users\PC\rssi_env\Lib\site-packages\sqlalchemy\engine\base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File c:\Users\PC\rssi_env\Lib\site-packages\sqlalchemy\engine\base.py:2363, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2362     assert sqlalchemy_exception is not None
# -> 2363     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2364 else:
#
# File c:\Users\PC\rssi_env\Lib\site-packages\sqlalchemy\engine\base.py:1936, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1935     if not evt_handled:
# -> 1936         self.dialect.do_executemany(
#    1937             cursor,
#    1938             str_statement,
#    1939             effective_parameters,
#    1940             context,
#    1941         )
#    1942 elif not effective_parameters and context.no_parameters:
#
# File c:\Users\PC\rssi_env\Lib\site-packages\sqlalchemy\engine\default.py:949, in DefaultDialect.do_executemany(self, cursor, statement, parameters, context)
#     948 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 949     cursor.executemany(statement, parameters)
#
# OperationalError: (sqlite3.OperationalError) database is locked
# [SQL: INSERT INTO books (title, author_id, isbn, publication_year, genre, copies_available) VALUES (?, ?, ?, ?, ?, ?)]
# [parameters: [('New Book 1', 1, '978-1234567890', 2024, 'Fiction', 3), ('New Book 2', 2, '978-0987654321', 2024, 'Biography', 2)]]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[25], line 16
#       1 # ─────────────────────────────────────────────
#       2 # Method 3: Writing DataFrames directly to database
#       3 # if_exists options: 'replace' (drop & recreate), 'append' (add rows), 'fail' (raise error)
#       4 # ─────────────────────────────────────────────
#       5 new_books_df = pd.DataFrame(
#       6     {
#       7         'title': ['New Book 1', 'New Book 2'],
#    (...)     13     }
#      14 )
# ---> 16 new_books_df.to_sql(
#      17     'books',
#      18     engine,
#      19     if_exists='append',  # Append to existing table
#      20     index=False,  # Don't write DataFrame index as a column
#      21 )
#      22 print("New books added successfully!")
#
# File c:\Users\PC\rssi_env\Lib\site-packages\pandas\core\generic.py:3052, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2820 """
#    2821 Write records stored in a DataFrame to a SQL database.
#    2822
#    (...)   3048 3
#    3049 """  # noqa: E501
#    3050 from pandas.io import sql
# -> 3052 return sql.to_sql(
#    3053     self,
#    3054     name,
#    3055     con,
#    3056     schema=schema,
#    3057     if_exists=if_exists,
#    3058     index=index,
#    3059     index_label=index_label,
#    3060     chunksize=chunksize,
#    3061     dtype=dtype,
#    3062     method=method,
#    3063 )
#
# File c:\Users\PC\rssi_env\Lib\site-packages\pandas\io\sql.py:841, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     836     raise NotImplementedError(
#     837         "'frame' argument should be either a Series or a DataFrame"
#     838     )
#     840 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 841     return pandas_sql.to_sql(
#     842         frame,
#     843         name,
#     844         if_exists=if_exists,
#     845         index=index,
#     846         index_label=index_label,
#     847         schema=schema,
#     848         chunksize=chunksize,
#     849         dtype=dtype,
#     850         method=method,
#     851         engine=engine,
#     852         **engine_kwargs,
#     853     )
#
# File c:\Users\PC\rssi_env\Lib\site-packages\pandas\io\sql.py:2037, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2025 sql_engine = get_engine(engine)
#    2027 table = self.prep_table(
#    2028     frame=frame,
#    2029     name=name,
#    (...)   2034     dtype=dtype,
#    2035 )
# -> 2037 total_inserted = sql_engine.insert_records(
#    2038     table=table,
#    2039     con=self.con,
#    2040     frame=frame,
#    2041     name=name,
#    2042     index=index,
#    2043     schema=schema,
#    2044     chunksize=chunksize,
#    2045     method=method,
#    2046     **engine_kwargs,
#    2047 )
#    2049 self.check_case_sensitive(name=name, schema=schema)
#    2050 return total_inserted
#
# File c:\Users\PC\rssi_env\Lib\site-packages\pandas\io\sql.py:1571, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1568 from sqlalchemy import exc
#    1570 try:
# -> 1571     return table.insert(chunksize=chunksize, method=method)
#    1572 except exc.StatementError as err:
#    1573     # GH34431
#    1574     # https://stackoverflow.com/a/67358288/6067848
#    1575     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1576     )|inf can not be used with MySQL"""
#
# File c:\Users\PC\rssi_env\Lib\site-packages\pandas\io\sql.py:1122, in SQLTable.insert(self, chunksize, method)
#    1117     break
#    1119 chunk_iter = zip(
#    1120     *(arr[start_i:end_i] for arr in data_list), strict=True
#    1121 )
# -> 1122 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1123 # GH 46891
#    1124 if num_inserted is not None:
#
# File c:\Users\PC\rssi_env\Lib\site-packages\pandas\io\sql.py:1014, in SQLTable._execute_insert(self, conn, keys, data_iter)
#    1002 """
#    1003 Execute SQL statement inserting data
#    1004
#    (...)   1011    Each item contains a list of values to be inserted
#    1012 """
#    1013 data = [dict(zip(keys, row, strict=True)) for row in data_iter]
# -> 1014 result = self.pd_sql.execute(self.table.insert(), data)
#    1015 return result.rowcount
#
# File c:\Users\PC\rssi_env\Lib\site-packages\pandas\io\sql.py:1681, in SQLDatabase.execute(self, sql, params)
#    1679     return execute_function(sql, *args)
#    1680 except SQLAlchemyError as exc:
# -> 1681     raise DatabaseError(f"Execution failed on sql '{sql}': {exc}") from exc
#
# DatabaseError: Execution failed on sql 'INSERT INTO books (title, author_id, isbn, publication_year, genre, copies_available) VALUES (:title, :author_id, :isbn, :publication_year, :genre, :copies_available)': (sqlite3.OperationalError) database is locked
# [SQL: INSERT INTO books (title, author_id, isbn, publication_year, genre, copies_available) VALUES (?, ?, ?, ?, ?, ?)]
# [parameters: [('New Book 1', 1, '978-1234567890', 2024, 'Fiction', 3), ('New Book 2', 2, '978-0987654321', 2024, 'Biography', 2)]]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# ─────────────────────────────────────────────
# Method 4: Chunked reading for large datasets
# Instead of loading millions of rows at once, process in chunks
# ─────────────────────────────────────────────
chunk_size = 1000  # Process 1000 rows at a time
for chunk in pd.read_sql("select * from borrowings", engine, chunksize=chunk_size):
    # Process each chunk (e.g., clean, transform, save)
    print(f"Processing {len(chunk)} rows...")
    # Your processing logic here
# Out:
# Processing 20 rows...

# %% [markdown]
# ### <span style="color:red">⚠️ SQL Injection Warning</span>
#
# ```python
# # ❌ DANGEROUS:
# user_input = "' OR '1'='1"  # Malicious input
# query = f"select * from members where email = '{user_input}'"
# # Results in: select * from members where email = '' OR '1'='1'
# # This returns ALL members! Security breach!
#
# # ✅ SAFE with SQLAlchemy parameterized queries:
# query = text("select * from members where email = :email")
# df = pd.read_sql(query, conn, params={'email': user_input})
# # SQLAlchemy escapes the input properly — malicious code is neutralized
# ```

# %% [markdown]
# ## 1.6 Graded Exercise 1: Library Database Analysis
#
# **Scenario:** The library director needs insights about the library's operations.
#
# ---
#
# ### Task 1: Basic Queries *(10 points)*
#
# Write SQL queries for the following. Save each result as a CSV file.
#
# **1.1** *(2 points)* Find all Fiction books published after 1960
# - Save as: `task1_1.csv`
# - Columns: `title`, `author_name`, `publication_year`
#
# **1.2** *(3 points)* List members with `'student'` membership who have borrowed books
# - Save as: `task1_2.csv`
# - Columns: `member_name`, `email`, `total_borrowings`
# - Sort by `total_borrowings desc`
#
# **1.3** *(5 points)* Calculate total fines collected per membership type
# - Save as: `task1_3.csv`
# - Columns: `membership_type`, `total_members`, `total_fines`, `avg_fine_per_member`
# - Only include members who have fines > 0

# %%
import os
import sqlite3
import pandas as pd
# Open the correct DB whether the notebook is run from project root or notebooks/.
db_path = 'library.db' if os.path.exists('library.db') else 'notebooks/library.db'
conn = sqlite3.connect(db_path)

# Task 1.1
query1_1 = """
select
    b.title,
    a.name as author_name,
    b.publication_year
from books b
inner join authors a ON b.author_id = a.author_id
where b.genre = 'Fiction'
  AND b.publication_year > 1960
order BY b.publication_year, b.title;
"""
df1_1 = pd.read_sql_query(query1_1, conn)
df1_1.to_csv('task1_1.csv', index=False)

# Task 1.2
query1_2 = """
select
    m.name as member_name,
    m.email,
    count(br.borrow_id) as total_borrowings
from members m
inner join borrowings br ON m.member_id = br.member_id
where m.membership_type = 'student'
group BY m.member_id, m.name, m.email
order BY total_borrowings desc;
"""
df1_2 = pd.read_sql_query(query1_2, conn)
df1_2.to_csv('task1_2.csv', index=False)

# Task 1.3
query1_3 = """
select
    m.membership_type,
    count(distinct m.member_id) as total_members,
    round(sum(br.fine_amount), 2) as total_fines,
    round(sum(br.fine_amount) / count(distinct m.member_id), 2) as avg_fine_per_member
from members m
inner join borrowings br ON m.member_id = br.member_id
where br.fine_amount > 0
group BY m.membership_type
order BY total_fines desc;
"""
df1_3 = pd.read_sql_query(query1_3, conn)
df1_3.to_csv('task1_3.csv', index=False)

conn.close()

# %% [markdown]
# ---
#
# ### Task 2: Advanced Analysis *(15 points)*
#
# **2.1** *(7 points)* Find the top 3 most popular books (most borrowed)
# - Save as: `task2_1.csv`
# - Columns: `title`, `author_name`, `times_borrowed`, `currently_available`
# - Include books with 0 borrowings showing "Never Borrowed"
#
# **2.2** *(8 points)* Identify overdue books (not yet returned and past due date)
# - Save as: `task2_2.csv`
# - Columns: `book_title`, `borrower_name`, `borrow_date`, `due_date`, `days_overdue`, `estimated_fine`
# - Calculate estimated fine as: `days_overdue * 2 EGP`
# - Sort by `days_overdue desc`

# %%
query2_1 = """
select
    b.title,
    a.name as author_name,
    CASE
        WHEN count(br.borrow_id) = 0 THEN 'Never Borrowed'
        ELSE CAST(count(br.borrow_id) as TEXT)
    END as times_borrowed,
    CASE
        WHEN b.copies_available > 0 THEN 'yes'
        ELSE 'no'
    END as currently_available
from books b
inner join authors a ON b.author_id = a.author_id
LEFT join borrowings br ON b.book_id = br.book_id
group BY b.book_id
order BY count(br.borrow_id) desc
LIMIT 3;
"""
df2_1 = pd.read_sql_query(query2_1, conn)
df2_1.to_csv('task2_1.csv', index=False)

query2_2 = """
select
    b.title as book_title,
    m.name as borrower_name,
    br.borrow_date,
    br.due_date,
    CAST(JULIANDAY(CURRENT_DATE) - JULIANDAY(br.due_date) as INTEGER) as days_overdue,
    CAST(JULIANDAY(CURRENT_DATE) - JULIANDAY(br.due_date) as INTEGER) * 2 as estimated_fine
from borrowings br
inner join books b ON br.book_id = b.book_id
inner join members m ON br.member_id = m.member_id
where br.return_date IS NULL
  AND br.due_date < CURRENT_DATE
order BY days_overdue desc
"""
df2_2 = pd.read_sql_query(query2_2, conn)
df2_2.to_csv('task2_2.csv', index=False)

# %% [markdown]
# ---
#
# ### Task 3: Complex Analysis with CTEs *(15 points)*
#
# **3.1** *(15 points)* Create a comprehensive member activity report
# - Save as: `task3_1.csv`
#
# **Required columns:**
# | Column | Description |
# |---|---|
# | `member_name` | Member's name |
# | `membership_type` | student / faculty / public |
# | `total_borrowings` | Total books borrowed |
# | `books_returned` | count of returned books |
# | `books_still_borrowed` | count still out |
# | `total_fines_paid` | sum of all fines |
# | `on_time_return_rate` | Percentage returned on time |
# | `member_category` | `'Inactive'` (0), `'Active'` (1–5), `'Very Active'` (>5) |

# %%
query3_1 = """
WITH member_borrowing_stats as (
    select
        m.member_id,
        m.name as member_name,
        m.membership_type,
        count(br.borrow_id) as total_borrowings,
        count(br.return_date) as books_returned,
        sum(case when br.borrow_id IS NOT NULL AND br.return_date IS NULL THEN 1 ELSE 0 END) as books_still_borrowed,
        sum(br.fine_amount) as total_fines_paid
    from members m
    left join borrowings br on m.member_id = br.member_id
    group by m.member_id
),
return_performance as (
    select
        br.member_id,
        sum(case when br.return_date IS NOT NULL AND br.return_date <= br.due_date THEN 1 ELSE 0 END) as on_time_returns,
        sum(case when br.return_date IS NOT NULL THEN 1 ELSE 0 END) as returned_count
    from borrowings br
    group by br.member_id
)
select
    mbs.member_name,
    mbs.membership_type,
    mbs.total_borrowings,
    mbs.books_returned,
    mbs.books_still_borrowed,
    mbs.total_fines_paid,
    round(
        COALESCE(
            (rp.on_time_returns * 100.0) / NULLIF(rp.returned_count, 0),
            0
        ),
        2
    ) as on_time_return_rate,
    CASE
        WHEN mbs.total_borrowings = 0 THEN 'Inactive'
        WHEN mbs.total_borrowings BETWEEN 1 AND 5 THEN 'Active'
        ELSE 'Very Active'
    END as member_category
from member_borrowing_stats mbs
LEFT join return_performance rp ON mbs.member_id = rp.member_id
order BY mbs.total_borrowings desc, mbs.member_name ASC;
"""
df3_1 = pd.read_sql_query(query3_1, conn)
df3_1.to_csv('task3_1.csv', index=False)

# %% [markdown]
# ---
#
# ### Submission Requirements:
# 1. 📄 Python script with all queries
# 2. 📊 Six CSV files: `task1_1.csv`, `task1_2.csv`, `task1_3.csv`, `task2_1.csv`, `task2_2.csv`, `task3_1.csv`
# 3. 📝 Brief report (1 paragraph) explaining your findings
#
# ### Grading Rubric:
# | Criterion | Weight |
# |---|---|
# | Query correctness | **60%** |
# | Output format (correct columns, sorted) | **20%** |
# | Code quality (comments, readable) | **10%** |
# | Report insights | **10%** |
#
# ---
# *End of Part 1: Database Access & SQL Mastery*

# %% [markdown]
# my findings are:
# task1_2 says that fatima is the most borrow student.
# task1_3 says descibe total_members,total_fines,avg_fine_per_member for student and faculty.
